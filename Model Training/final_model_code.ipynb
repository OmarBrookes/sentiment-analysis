# %% [markdown]
# Load Trained RoBERTa Model

# %%
from transformers import RobertaTokenizer, RobertaForSequenceClassification

# Path to the saved model folder
model_path = "./roberta-multilabel-full"

# Load tokenizer and model from the saved directory
tokenizer = RobertaTokenizer.from_pretrained(model_path)
model = RobertaForSequenceClassification.from_pretrained(model_path)

# Move model to device
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

print("Loaded model and tokenizer from:", model_path)
# Out:
# Loaded model and tokenizer from: ./roberta-multilabel-full

# %% [markdown]
# Set up Trainer for evaluation/inference

# %%
from transformers import Trainer

trainer = Trainer(model=model)
print("Trainer is ready for predictions or evaluation.")
# Out:
# Trainer is ready for predictions or evaluation.

# %% [markdown]
# Precision, Recall, F1-Score Table

# %%
import pandas as pd
from torch.utils.data import Dataset
from transformers import RobertaTokenizer

# Load CSV
df = pd.read_csv("batch.400K(no_dupe).csv")

# Extract labels
all_possible_labels = ['neutral', 'positive', 'mixed', 'sarcastic', 'negative', 'ironic']

# Convert the multi-label list into binary columns
for label in all_possible_labels:
    df[label] = df['label_list'].apply(lambda x: int(label in x.strip("[]").replace("'", "").split(", ")))

test_df = df.copy()

# Custom dataset class
class MultiLabelDataset(Dataset):
    def __init__(self, dataframe, tokenizer):
        self.texts = dataframe["tweet"].tolist()
        self.labels = dataframe[all_possible_labels].values.tolist()
        self.tokenizer = tokenizer

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        text = self.texts[idx]
        labels = torch.tensor(self.labels[idx], dtype=torch.float)
        encoding = self.tokenizer(text, truncation=True, padding="max_length", max_length=128, return_tensors="pt")
        encoding = {k: v.squeeze() for k, v in encoding.items()}
        encoding["labels"] = labels
        return encoding

# Tokenizer
tokenizer = RobertaTokenizer.from_pretrained("roberta-base")

# Dataset
test_dataset = MultiLabelDataset(test_df, tokenizer)

# %%
from sklearn.metrics import classification_report
import numpy as np
import torch

# Set device (GPU if available)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# Make sure trainer also uses the correct device (important)
trainer.model.to(device)

# Evaluate the model on test set
predictions = trainer.predict(test_dataset)

# Convert logits to probabilities and apply threshold
probs = torch.sigmoid(torch.tensor(predictions.predictions))
y_pred = (probs >= 0.5).int().numpy()
y_true = predictions.label_ids.astype(int)

# Generate classification report
report = classification_report(
    y_true, y_pred,
    target_names=all_possible_labels,
    zero_division=0
)
print("Classification Report (Multi-Label):")
print(report)
# Out:
#   0%|          | 0/43123 [00:00<?, ?it/s]
# 📋 Classification Report (Multi-Label):
#               precision    recall  f1-score   support
#
#      neutral       0.80      0.52      0.63     43823
#     positive       0.91      0.89      0.90     94529
#        mixed       0.70      0.48      0.57     45435
#    sarcastic       0.86      0.53      0.66     61810
#     negative       0.87      0.85      0.86    110051
#       ironic       0.73      0.58      0.65     50494
#
#    micro avg       0.84      0.70      0.76    406142
#    macro avg       0.81      0.64      0.71    406142
# weighted avg       0.83      0.70      0.75    406142
#  samples avg       0.79      0.74      0.75    406142

# %% [markdown]
# Test Reviews Without Custom Thresholds

# %%
import torch

# Label names
label_names = ['neutral', 'positive', 'mixed', 'sarcastic', 'negative', 'ironic']

# Test review examples with expected labels
test_reviews = [
    # Positive
    ("Absolutely amazing product! It exceeded my expectations!", ["positive"]),
    ("Fantastic service, will definitely use again!", ["positive"]),
    ("This is hands down the best thing I’ve bought!", ["positive"]),
    ("I love it! Works perfectly every time.", ["positive"]),
    ("Exceeded expectations, truly outstanding!", ["positive"]),

    # Negative
    ("Horrible experience, I regret buying this.", ["negative"]),
    ("The worst purchase I’ve ever made. Never again!", ["negative"]),
    ("Disappointed. The quality is awful and not worth the price.", ["negative"]),
    ("Terrible. Nothing works as promised.", ["negative"]),
    ("Awful experience. I want my money back.", ["negative"]),

    # Neutral
    ("It’s okay, not great but not bad either.", ["neutral"]),
    ("I guess it does what it says, nothing special.", ["neutral"]),
    ("Nothing extraordinary, just a standard product.", ["neutral"]),
    ("Average performance, can't complain.", ["neutral"]),
    ("Mediocre. Doesn’t stand out but not bad.", ["neutral"]),

    # Mixed
    ("I love the design, but the functionality is terrible.", ["mixed"]),
    ("Good concept, poor execution.", ["mixed"]),
    ("Some features are great, but overall I wouldn’t recommend.", ["mixed"]),
    ("Pros and cons — I’m undecided.", ["mixed"]),
    ("Both impressed and let down in equal measure.", ["mixed"]),

    # Sarcastic + Negative
    ("Oh wow, just what I always wanted… NOT!", ["sarcastic", "negative"]),
    ("Oh fantastic, another useless update.", ["sarcastic", "negative"]),
    ("Brilliant! Said no one ever about this junk.", ["sarcastic", "negative"]),
    ("Great job breaking everything. Again.", ["sarcastic", "negative"]),
    ("Oh joy, it broke immediately. Amazing!", ["sarcastic", "negative"]),

    # Sarcastic + Neutral
    ("Yeah, sure… this is exactly what I expected.", ["sarcastic", "neutral"]),
    ("Well, isn’t this just the best thing ever?", ["sarcastic", "neutral"]),
    ("Oh sure, this product totally changed my life…", ["sarcastic", "neutral"]),
    ("Exactly the same as every other generic product. Wow.", ["sarcastic", "neutral"]),
    ("Super exciting… not really.", ["sarcastic", "neutral"]),

    # Sarcastic + Mixed
    ("Wow, I’m so happy with this… if only it actually worked.", ["sarcastic", "mixed"]),
    ("Oh great, another 'amazing' feature that nobody asked for.", ["sarcastic", "mixed"]),
    ("So close to perfect… but also kinda trash.", ["sarcastic", "mixed"]),
    ("Fantastic in theory, disaster in practice. Bravo!", ["sarcastic", "mixed"]),
    ("Sure, half the features are broken — innovation!", ["sarcastic", "mixed"]),

    # Ironic + Positive
    ("Oh look, another perfect example of a flawless product.", ["ironic", "positive"]),
    ("A real masterpiece… if sarcasm were a metric.", ["ironic", "positive"]),
    ("What a gem — just kidding, it's actually useful!", ["ironic", "positive"]),
    ("Flawless execution… on how not to build a product.", ["ironic", "positive"]),
    ("So perfect it’s almost unbelievable. Literally.", ["ironic", "positive"]),

    # Ironic + Mixed
    ("Sure, best device ever… if it didn’t break on day one.", ["ironic", "mixed"]),
    ("Perfect! If by perfect you mean completely broken.", ["ironic", "mixed"]),
    ("Oh sure, they totally listened to our feedback…", ["ironic", "mixed"]),
    ("Incredible design paired with questionable logic.", ["ironic", "mixed"]),
    ("So helpful it made things worse!", ["ironic", "mixed"]),

    # Ironic + Neutral
    ("Oh wow, an update that fixes nothing!", ["ironic", "neutral"]),
    ("Great, the bug is still there.", ["ironic", "neutral"]),
    ("Exactly the same — impressively unchanged!", ["ironic", "neutral"]),
    ("Just as dull as the last version. Yay.", ["ironic", "neutral"]),
    ("Another average miracle.", ["ironic", "neutral"]),

    # Ironic + Negative
    ("Oh brilliant, I just wasted my money.", ["ironic", "negative"]),
    ("Wonderful, my brand-new product stopped working after a day.", ["ironic", "negative"]),
    ("Lovely, it crashes faster than it loads.", ["ironic", "negative"]),
    ("Fabulous! Now I have two broken things instead of one.", ["ironic", "negative"]),
    ("Perfect failure — can’t top this mess.", ["ironic", "negative"]),

    # Ambiguous / Edge
    ("I don’t know what to think about this.", ["neutral"]),
    ("It’s both good and bad, I really can't decide.", ["mixed"]),
    ("I have mixed feelings about it.", ["mixed"]),
    ("It's okay, but I kind of hate it too.", ["mixed", "sarcastic"]),
    ("Some days I love it, some days I want to throw it out.", ["mixed", "ironic"])
]

custom_thresholds = {
    'neutral': 0.39,
    'positive': 0.509,
    'mixed': 0.22,
    'sarcastic': 0.29,
    'negative': 0.428,
    'ironic': 0.16
}

# Prediction using updated custom thresholds
def predict_custom_thresholds(text):
    encoding = tokenizer(text, return_tensors="pt", truncation=True, padding="max_length", max_length=128)
    encoding = {k: v.to(model.device) for k, v in encoding.items()}

    with torch.no_grad():
        logits = model(**encoding).logits
        probs = torch.sigmoid(logits)[0].cpu().numpy()

    preds = [label_names[i] for i, p in enumerate(probs) if p >= custom_thresholds[label_names[i]]]
    return preds, probs

# Run predictions on test reviews using updated thresholds
for i, (review, expected) in enumerate(test_reviews, 1):
    predicted_labels, probabilities = predict_custom_thresholds(review)
    print(f"\n🔹 Review #{i}")
    print(f"📝 Text: {review}")
    print(f"🎯 Expected: {expected}")
    print(f"✅ Predicted: {predicted_labels}")
    print("📊 Probabilities:", {label_names[j]: round(prob, 3) for j, prob in enumerate(probabilities)})
    print("-" * 60)
# Out:
# 🔹 Review #1
# 📝 Text: Absolutely amazing product! It exceeded my expectations!
# 🎯 Expected: ['positive']
# ✅ Predicted: ['positive']
# 📊 Probabilities: {'neutral': 0.001, 'positive': 0.993, 'mixed': 0.003, 'sarcastic': 0.011, 'negative': 0.005, 'ironic': 0.003}
# ------------------------------------------------------------
#
# 🔹 Review #2
# 📝 Text: Fantastic service, will definitely use again!
# 🎯 Expected: ['positive']
# ✅ Predicted: ['positive']
# 📊 Probabilities: {'neutral': 0.001, 'positive': 0.981, 'mixed': 0.004, 'sarcastic': 0.267, 'negative': 0.011, 'ironic': 0.006}
# ------------------------------------------------------------
#
# 🔹 Review #3
# 📝 Text: This is hands down the best thing I’ve bought!
# 🎯 Expected: ['positive']
# ✅ Predicted: ['positive']
# 📊 Probabilities: {'neutral': 0.008, 'positive': 0.923, 'mixed': 0.008, 'sarcastic': 0.111, 'negative': 0.003, 'ironic': 0.036}
# ------------------------------------------------------------
#
# 🔹 Review #4
# 📝 Text: I love it! Works perfectly every time.
# 🎯 Expected: ['positive']
# ✅ Predicted: ['positive']
# 📊 Probabilities: {'neutral': 0.002, 'positive': 0.992, 'mixed': 0.004, 'sarcastic': 0.007, 'negative': 0.005, 'ironic': 0.002}
# ------------------------------------------------------------
#
# 🔹 Review #5
# 📝 Text: Exceeded expectations, truly outstanding!
# 🎯 Expected: ['positive']
# ✅ Predicted: ['positive']
# 📊 Probabilities: {'neutral': 0.004, 'positive': 0.949, 'mixed': 0.013, 'sarcastic': 0.061, 'negative': 0.044, 'ironic': 0.004}
# ------------------------------------------------------------
#
# 🔹 Review #6
# 📝 Text: Horrible experience, I regret buying this.
# 🎯 Expected: ['negative']
# ✅ Predicted: ['negative']
# 📊 Probabilities: {'neutral': 0.002, 'positive': 0.008, 'mixed': 0.003, 'sarcastic': 0.019, 'negative': 0.992, 'ironic': 0.007}
# ------------------------------------------------------------
#
# 🔹 Review #7
# 📝 Text: The worst purchase I’ve ever made. Never again!
# 🎯 Expected: ['negative']
# ✅ Predicted: ['negative']
# 📊 Probabilities: {'neutral': 0.005, 'positive': 0.002, 'mixed': 0.006, 'sarcastic': 0.137, 'negative': 0.927, 'ironic': 0.148}
# ------------------------------------------------------------
#
# 🔹 Review #8
# 📝 Text: Disappointed. The quality is awful and not worth the price.
# 🎯 Expected: ['negative']
# ✅ Predicted: ['negative']
# 📊 Probabilities: {'neutral': 0.005, 'positive': 0.008, 'mixed': 0.005, 'sarcastic': 0.011, 'negative': 0.991, 'ironic': 0.005}
# ------------------------------------------------------------
#
# 🔹 Review #9
# 📝 Text: Terrible. Nothing works as promised.
# 🎯 Expected: ['negative']
# ✅ Predicted: ['negative']
# 📊 Probabilities: {'neutral': 0.004, 'positive': 0.008, 'mixed': 0.004, 'sarcastic': 0.014, 'negative': 0.991, 'ironic': 0.006}
# ------------------------------------------------------------
#
# 🔹 Review #10
# 📝 Text: Awful experience. I want my money back.
# 🎯 Expected: ['negative']
# ✅ Predicted: ['negative']
# 📊 Probabilities: {'neutral': 0.004, 'positive': 0.01, 'mixed': 0.003, 'sarcastic': 0.011, 'negative': 0.99, 'ironic': 0.005}
# ------------------------------------------------------------
#
# 🔹 Review #11
# 📝 Text: It’s okay, not great but not bad either.
# 🎯 Expected: ['neutral']
# ✅ Predicted: ['neutral', 'mixed']
# 📊 Probabilities: {'neutral': 0.461, 'positive': 0.004, 'mixed': 0.678, 'sarcastic': 0.003, 'negative': 0.006, 'ironic': 0.007}
# ------------------------------------------------------------
#
# 🔹 Review #12
# 📝 Text: I guess it does what it says, nothing special.
# 🎯 Expected: ['neutral']
# ✅ Predicted: ['neutral']
# 📊 Probabilities: {'neutral': 0.972, 'positive': 0.003, 'mixed': 0.048, 'sarcastic': 0.005, 'negative': 0.003, 'ironic': 0.012}
# ------------------------------------------------------------
#
# 🔹 Review #13
# 📝 Text: Nothing extraordinary, just a standard product.
# 🎯 Expected: ['neutral']
# ✅ Predicted: ['neutral']
# 📊 Probabilities: {'neutral': 0.986, 'positive': 0.005, 'mixed': 0.013, 'sarcastic': 0.008, 'negative': 0.006, 'ironic': 0.008}
# ------------------------------------------------------------
#
# 🔹 Review #14
# 📝 Text: Average performance, can't complain.
# 🎯 Expected: ['neutral']
# ✅ Predicted: ['neutral']
# 📊 Probabilities: {'neutral': 0.981, 'positive': 0.007, 'mixed': 0.02, 'sarcastic': 0.005, 'negative': 0.006, 'ironic': 0.006}
# ------------------------------------------------------------
#
# 🔹 Review #15
# 📝 Text: Mediocre. Doesn’t stand out but not bad.
# 🎯 Expected: ['neutral']
# ✅ Predicted: ['neutral', 'mixed']
# 📊 Probabilities: {'neutral': 0.468, 'positive': 0.003, 'mixed': 0.27, 'sarcastic': 0.023, 'negative': 0.203, 'ironic': 0.019}
# ------------------------------------------------------------
#
# 🔹 Review #16
# 📝 Text: I love the design, but the functionality is terrible.
# 🎯 Expected: ['mixed']
# ✅ Predicted: ['positive', 'negative']
# 📊 Probabilities: {'neutral': 0.029, 'positive': 0.906, 'mixed': 0.078, 'sarcastic': 0.003, 'negative': 0.909, 'ironic': 0.001}
# ------------------------------------------------------------
#
# 🔹 Review #17
# 📝 Text: Good concept, poor execution.
# 🎯 Expected: ['mixed']
# ✅ Predicted: ['mixed', 'negative']
# 📊 Probabilities: {'neutral': 0.013, 'positive': 0.188, 'mixed': 0.301, 'sarcastic': 0.003, 'negative': 0.868, 'ironic': 0.002}
# ------------------------------------------------------------
#
# 🔹 Review #18
# 📝 Text: Some features are great, but overall I wouldn’t recommend.
# 🎯 Expected: ['mixed']
# ✅ Predicted: ['mixed']
# 📊 Probabilities: {'neutral': 0.19, 'positive': 0.045, 'mixed': 0.822, 'sarcastic': 0.003, 'negative': 0.07, 'ironic': 0.003}
# ------------------------------------------------------------
#
# 🔹 Review #19
# 📝 Text: Pros and cons — I’m undecided.
# 🎯 Expected: ['mixed']
# ✅ Predicted: ['neutral']
# 📊 Probabilities: {'neutral': 0.955, 'positive': 0.006, 'mixed': 0.051, 'sarcastic': 0.003, 'negative': 0.005, 'ironic': 0.003}
# ------------------------------------------------------------
#
# 🔹 Review #20
# 📝 Text: Both impressed and let down in equal measure.
# 🎯 Expected: ['mixed']
# ✅ Predicted: ['mixed']
# 📊 Probabilities: {'neutral': 0.046, 'positive': 0.006, 'mixed': 0.957, 'sarcastic': 0.005, 'negative': 0.008, 'ironic': 0.014}
# ------------------------------------------------------------
#
# 🔹 Review #21
# 📝 Text: Oh wow, just what I always wanted… NOT!
# 🎯 Expected: ['sarcastic', 'negative']
# ✅ Predicted: ['sarcastic', 'negative']
# 📊 Probabilities: {'neutral': 0.006, 'positive': 0.099, 'mixed': 0.01, 'sarcastic': 0.905, 'negative': 0.806, 'ironic': 0.049}
# ------------------------------------------------------------
#
# 🔹 Review #22
# 📝 Text: Oh fantastic, another useless update.
# 🎯 Expected: ['sarcastic', 'negative']
# ✅ Predicted: ['sarcastic', 'negative']
# 📊 Probabilities: {'neutral': 0.002, 'positive': 0.012, 'mixed': 0.002, 'sarcastic': 0.774, 'negative': 0.982, 'ironic': 0.035}
# ------------------------------------------------------------
#
# 🔹 Review #23
# 📝 Text: Brilliant! Said no one ever about this junk.
# 🎯 Expected: ['sarcastic', 'negative']
# ✅ Predicted: ['sarcastic']
# 📊 Probabilities: {'neutral': 0.006, 'positive': 0.109, 'mixed': 0.013, 'sarcastic': 0.868, 'negative': 0.209, 'ironic': 0.1}
# ------------------------------------------------------------
#
# 🔹 Review #24
# 📝 Text: Great job breaking everything. Again.
# 🎯 Expected: ['sarcastic', 'negative']
# ✅ Predicted: ['sarcastic', 'negative']
# 📊 Probabilities: {'neutral': 0.003, 'positive': 0.053, 'mixed': 0.005, 'sarcastic': 0.924, 'negative': 0.932, 'ironic': 0.049}
# ------------------------------------------------------------
#
# 🔹 Review #25
# 📝 Text: Oh joy, it broke immediately. Amazing!
# 🎯 Expected: ['sarcastic', 'negative']
# ✅ Predicted: ['sarcastic', 'negative']
# 📊 Probabilities: {'neutral': 0.003, 'positive': 0.129, 'mixed': 0.005, 'sarcastic': 0.975, 'negative': 0.871, 'ironic': 0.036}
# ------------------------------------------------------------
#
# 🔹 Review #26
# 📝 Text: Yeah, sure… this is exactly what I expected.
# 🎯 Expected: ['sarcastic', 'neutral']
# ✅ Predicted: ['sarcastic', 'negative']
# 📊 Probabilities: {'neutral': 0.023, 'positive': 0.036, 'mixed': 0.013, 'sarcastic': 0.96, 'negative': 0.871, 'ironic': 0.036}
# ------------------------------------------------------------
#
# 🔹 Review #27
# 📝 Text: Well, isn’t this just the best thing ever?
# 🎯 Expected: ['sarcastic', 'neutral']
# ✅ Predicted: ['positive', 'sarcastic']
# 📊 Probabilities: {'neutral': 0.012, 'positive': 0.719, 'mixed': 0.023, 'sarcastic': 0.76, 'negative': 0.127, 'ironic': 0.062}
# ------------------------------------------------------------
#
# 🔹 Review #28
# 📝 Text: Oh sure, this product totally changed my life…
# 🎯 Expected: ['sarcastic', 'neutral']
# ✅ Predicted: ['sarcastic', 'negative']
# 📊 Probabilities: {'neutral': 0.001, 'positive': 0.217, 'mixed': 0.004, 'sarcastic': 0.945, 'negative': 0.693, 'ironic': 0.053}
# ------------------------------------------------------------
#
# 🔹 Review #29
# 📝 Text: Exactly the same as every other generic product. Wow.
# 🎯 Expected: ['sarcastic', 'neutral']
# ✅ Predicted: ['sarcastic', 'negative', 'ironic']
# 📊 Probabilities: {'neutral': 0.081, 'positive': 0.017, 'mixed': 0.015, 'sarcastic': 0.637, 'negative': 0.783, 'ironic': 0.173}
# ------------------------------------------------------------
#
# 🔹 Review #30
# 📝 Text: Super exciting… not really.
# 🎯 Expected: ['sarcastic', 'neutral']
# ✅ Predicted: ['sarcastic', 'negative', 'ironic']
# 📊 Probabilities: {'neutral': 0.088, 'positive': 0.029, 'mixed': 0.145, 'sarcastic': 0.706, 'negative': 0.454, 'ironic': 0.321}
# ------------------------------------------------------------
#
# 🔹 Review #31
# 📝 Text: Wow, I’m so happy with this… if only it actually worked.
# 🎯 Expected: ['sarcastic', 'mixed']
# ✅ Predicted: ['mixed', 'sarcastic']
# 📊 Probabilities: {'neutral': 0.039, 'positive': 0.022, 'mixed': 0.267, 'sarcastic': 0.824, 'negative': 0.029, 'ironic': 0.081}
# ------------------------------------------------------------
#
# 🔹 Review #32
# 📝 Text: Oh great, another 'amazing' feature that nobody asked for.
# 🎯 Expected: ['sarcastic', 'mixed']
# ✅ Predicted: ['sarcastic']
# 📊 Probabilities: {'neutral': 0.008, 'positive': 0.059, 'mixed': 0.008, 'sarcastic': 0.952, 'negative': 0.134, 'ironic': 0.075}
# ------------------------------------------------------------
#
# 🔹 Review #33
# 📝 Text: So close to perfect… but also kinda trash.
# 🎯 Expected: ['sarcastic', 'mixed']
# ✅ Predicted: ['mixed']
# 📊 Probabilities: {'neutral': 0.037, 'positive': 0.002, 'mixed': 0.939, 'sarcastic': 0.021, 'negative': 0.013, 'ironic': 0.054}
# ------------------------------------------------------------
#
# 🔹 Review #34
# 📝 Text: Fantastic in theory, disaster in practice. Bravo!
# 🎯 Expected: ['sarcastic', 'mixed']
# ✅ Predicted: ['mixed', 'sarcastic']
# 📊 Probabilities: {'neutral': 0.006, 'positive': 0.192, 'mixed': 0.466, 'sarcastic': 0.673, 'negative': 0.057, 'ironic': 0.139}
# ------------------------------------------------------------
#
# 🔹 Review #35
# 📝 Text: Sure, half the features are broken — innovation!
# 🎯 Expected: ['sarcastic', 'mixed']
# ✅ Predicted: ['sarcastic']
# 📊 Probabilities: {'neutral': 0.004, 'positive': 0.042, 'mixed': 0.008, 'sarcastic': 0.957, 'negative': 0.062, 'ironic': 0.069}
# ------------------------------------------------------------
#
# 🔹 Review #36
# 📝 Text: Oh look, another perfect example of a flawless product.
# 🎯 Expected: ['ironic', 'positive']
# ✅ Predicted: ['sarcastic', 'negative']
# 📊 Probabilities: {'neutral': 0.003, 'positive': 0.326, 'mixed': 0.007, 'sarcastic': 0.951, 'negative': 0.672, 'ironic': 0.037}
# ------------------------------------------------------------
#
# 🔹 Review #37
# 📝 Text: A real masterpiece… if sarcasm were a metric.
# 🎯 Expected: ['ironic', 'positive']
# ✅ Predicted: ['mixed', 'ironic']
# 📊 Probabilities: {'neutral': 0.029, 'positive': 0.001, 'mixed': 0.252, 'sarcastic': 0.281, 'negative': 0.001, 'ironic': 0.651}
# ------------------------------------------------------------
#
# 🔹 Review #38
# 📝 Text: What a gem — just kidding, it's actually useful!
# 🎯 Expected: ['ironic', 'positive']
# ✅ Predicted: ['sarcastic', 'ironic']
# 📊 Probabilities: {'neutral': 0.015, 'positive': 0.051, 'mixed': 0.074, 'sarcastic': 0.684, 'negative': 0.044, 'ironic': 0.376}
# ------------------------------------------------------------
#
# 🔹 Review #39
# 📝 Text: Flawless execution… on how not to build a product.
# 🎯 Expected: ['ironic', 'positive']
# ✅ Predicted: ['ironic']
# 📊 Probabilities: {'neutral': 0.028, 'positive': 0.002, 'mixed': 0.126, 'sarcastic': 0.241, 'negative': 0.084, 'ironic': 0.655}
# ------------------------------------------------------------
#
# 🔹 Review #40
# 📝 Text: So perfect it’s almost unbelievable. Literally.
# 🎯 Expected: ['ironic', 'positive']
# ✅ Predicted: ['sarcastic', 'ironic']
# 📊 Probabilities: {'neutral': 0.161, 'positive': 0.014, 'mixed': 0.151, 'sarcastic': 0.477, 'negative': 0.068, 'ironic': 0.452}
# ------------------------------------------------------------
#
# 🔹 Review #41
# 📝 Text: Sure, best device ever… if it didn’t break on day one.
# 🎯 Expected: ['ironic', 'mixed']
# ✅ Predicted: ['sarcastic', 'ironic']
# 📊 Probabilities: {'neutral': 0.014, 'positive': 0.003, 'mixed': 0.05, 'sarcastic': 0.853, 'negative': 0.003, 'ironic': 0.188}
# ------------------------------------------------------------
#
# 🔹 Review #42
# 📝 Text: Perfect! If by perfect you mean completely broken.
# 🎯 Expected: ['ironic', 'mixed']
# ✅ Predicted: ['sarcastic', 'ironic']
# 📊 Probabilities: {'neutral': 0.019, 'positive': 0.039, 'mixed': 0.071, 'sarcastic': 0.751, 'negative': 0.267, 'ironic': 0.323}
# ------------------------------------------------------------
#
# 🔹 Review #43
# 📝 Text: Oh sure, they totally listened to our feedback…
# 🎯 Expected: ['ironic', 'mixed']
# ✅ Predicted: ['sarcastic', 'negative']
# 📊 Probabilities: {'neutral': 0.006, 'positive': 0.091, 'mixed': 0.004, 'sarcastic': 0.978, 'negative': 0.576, 'ironic': 0.031}
# ------------------------------------------------------------
#
# 🔹 Review #44
# 📝 Text: Incredible design paired with questionable logic.
# 🎯 Expected: ['ironic', 'mixed']
# ✅ Predicted: ['mixed']
# 📊 Probabilities: {'neutral': 0.01, 'positive': 0.035, 'mixed': 0.905, 'sarcastic': 0.071, 'negative': 0.033, 'ironic': 0.068}
# ------------------------------------------------------------
#
# 🔹 Review #45
# 📝 Text: So helpful it made things worse!
# 🎯 Expected: ['ironic', 'mixed']
# ✅ Predicted: ['sarcastic', 'negative']
# 📊 Probabilities: {'neutral': 0.006, 'positive': 0.417, 'mixed': 0.058, 'sarcastic': 0.401, 'negative': 0.61, 'ironic': 0.048}
# ------------------------------------------------------------
#
# 🔹 Review #46
# 📝 Text: Oh wow, an update that fixes nothing!
# 🎯 Expected: ['ironic', 'neutral']
# ✅ Predicted: ['sarcastic', 'negative']
# 📊 Probabilities: {'neutral': 0.002, 'positive': 0.226, 'mixed': 0.004, 'sarcastic': 0.961, 'negative': 0.726, 'ironic': 0.053}
# ------------------------------------------------------------
#
# 🔹 Review #47
# 📝 Text: Great, the bug is still there.
# 🎯 Expected: ['ironic', 'neutral']
# ✅ Predicted: ['sarcastic', 'negative']
# 📊 Probabilities: {'neutral': 0.002, 'positive': 0.018, 'mixed': 0.001, 'sarcastic': 0.498, 'negative': 0.984, 'ironic': 0.031}
# ------------------------------------------------------------
#
# 🔹 Review #48
# 📝 Text: Exactly the same — impressively unchanged!
# 🎯 Expected: ['ironic', 'neutral']
# ✅ Predicted: ['neutral', 'sarcastic', 'ironic']
# 📊 Probabilities: {'neutral': 0.534, 'positive': 0.065, 'mixed': 0.093, 'sarcastic': 0.364, 'negative': 0.133, 'ironic': 0.187}
# ------------------------------------------------------------
#
# 🔹 Review #49
# 📝 Text: Just as dull as the last version. Yay.
# 🎯 Expected: ['ironic', 'neutral']
# ✅ Predicted: ['sarcastic', 'negative', 'ironic']
# 📊 Probabilities: {'neutral': 0.021, 'positive': 0.029, 'mixed': 0.074, 'sarcastic': 0.683, 'negative': 0.84, 'ironic': 0.293}
# ------------------------------------------------------------
#
# 🔹 Review #50
# 📝 Text: Another average miracle.
# 🎯 Expected: ['ironic', 'neutral']
# ✅ Predicted: ['neutral']
# 📊 Probabilities: {'neutral': 0.959, 'positive': 0.005, 'mixed': 0.071, 'sarcastic': 0.037, 'negative': 0.012, 'ironic': 0.107}
# ------------------------------------------------------------
#
# 🔹 Review #51
# 📝 Text: Oh brilliant, I just wasted my money.
# 🎯 Expected: ['ironic', 'negative']
# ✅ Predicted: ['sarcastic', 'negative']
# 📊 Probabilities: {'neutral': 0.002, 'positive': 0.042, 'mixed': 0.003, 'sarcastic': 0.948, 'negative': 0.944, 'ironic': 0.037}
# ------------------------------------------------------------
#
# 🔹 Review #52
# 📝 Text: Wonderful, my brand-new product stopped working after a day.
# 🎯 Expected: ['ironic', 'negative']
# ✅ Predicted: ['sarcastic', 'negative']
# 📊 Probabilities: {'neutral': 0.003, 'positive': 0.024, 'mixed': 0.003, 'sarcastic': 0.931, 'negative': 0.974, 'ironic': 0.04}
# ------------------------------------------------------------
#
# 🔹 Review #53
# 📝 Text: Lovely, it crashes faster than it loads.
# 🎯 Expected: ['ironic', 'negative']
# ✅ Predicted: ['sarcastic', 'negative']
# 📊 Probabilities: {'neutral': 0.002, 'positive': 0.05, 'mixed': 0.002, 'sarcastic': 0.914, 'negative': 0.967, 'ironic': 0.088}
# ------------------------------------------------------------
#
# 🔹 Review #54
# 📝 Text: Fabulous! Now I have two broken things instead of one.
# 🎯 Expected: ['ironic', 'negative']
# ✅ Predicted: ['sarcastic', 'negative']
# 📊 Probabilities: {'neutral': 0.002, 'positive': 0.209, 'mixed': 0.008, 'sarcastic': 0.935, 'negative': 0.767, 'ironic': 0.103}
# ------------------------------------------------------------
#
# 🔹 Review #55
# 📝 Text: Perfect failure — can’t top this mess.
# 🎯 Expected: ['ironic', 'negative']
# ✅ Predicted: ['negative']
# 📊 Probabilities: {'neutral': 0.007, 'positive': 0.005, 'mixed': 0.022, 'sarcastic': 0.119, 'negative': 0.932, 'ironic': 0.044}
# ------------------------------------------------------------
#
# 🔹 Review #56
# 📝 Text: I don’t know what to think about this.
# 🎯 Expected: ['neutral']
# ✅ Predicted: ['neutral']
# 📊 Probabilities: {'neutral': 0.985, 'positive': 0.006, 'mixed': 0.014, 'sarcastic': 0.006, 'negative': 0.006, 'ironic': 0.006}
# ------------------------------------------------------------
#
# 🔹 Review #57
# 📝 Text: It’s both good and bad, I really can't decide.
# 🎯 Expected: ['mixed']
# ✅ Predicted: ['mixed']
# 📊 Probabilities: {'neutral': 0.128, 'positive': 0.003, 'mixed': 0.895, 'sarcastic': 0.004, 'negative': 0.003, 'ironic': 0.012}
# ------------------------------------------------------------
#
# 🔹 Review #58
# 📝 Text: I have mixed feelings about it.
# 🎯 Expected: ['mixed']
# ✅ Predicted: ['mixed']
# 📊 Probabilities: {'neutral': 0.026, 'positive': 0.011, 'mixed': 0.975, 'sarcastic': 0.01, 'negative': 0.008, 'ironic': 0.014}
# ------------------------------------------------------------
#
# 🔹 Review #59
# 📝 Text: It's okay, but I kind of hate it too.
# 🎯 Expected: ['mixed', 'sarcastic']
# ✅ Predicted: ['mixed']
# 📊 Probabilities: {'neutral': 0.201, 'positive': 0.159, 'mixed': 0.687, 'sarcastic': 0.004, 'negative': 0.369, 'ironic': 0.004}
# ------------------------------------------------------------
#
# 🔹 Review #60
# 📝 Text: Some days I love it, some days I want to throw it out.
# 🎯 Expected: ['mixed', 'ironic']
# ✅ Predicted: ['mixed']
# 📊 Probabilities: {'neutral': 0.038, 'positive': 0.059, 'mixed': 0.937, 'sarcastic': 0.003, 'negative': 0.02, 'ironic': 0.007}
# ------------------------------------------------------------

# %% [markdown]
# Example Test for Report

# %%
import torch

# Label names
label_names = ['neutral', 'positive', 'mixed', 'sarcastic', 'negative', 'ironic']

test_reviews = [
    # Positive
    ("Absolutely amazing product! It exceeded my expectations!", ["positive"]),

    # Negative
    ("Horrible experience, I regret buying this.", ["negative"]),

    # Neutral
    ("It’s okay, not great but not bad either.", ["neutral"]),

    # Mixed
    ("I love the design, but the functionality is terrible.", ["mixed"]),

    # Sarcastic
    ("Oh wow, just what I always wanted… NOT!", ["sarcastic", "negative"]),

    # Ironic
    ("Nothing like spending hundreds on noise-cancelling headphones that let in every sound.", ["ironic", "negative"]),
]

custom_thresholds = {
    'neutral': 0.39,
    'positive': 0.509,
    'mixed': 0.22,
    'sarcastic': 0.29,
    'negative': 0.428,
    'ironic': 0.16
}

# Prediction using updated custom thresholds
def predict_custom_thresholds(text):
    encoding = tokenizer(text, return_tensors="pt", truncation=True, padding="max_length", max_length=128)
    encoding = {k: v.to(model.device) for k, v in encoding.items()}

    with torch.no_grad():
        logits = model(**encoding).logits
        probs = torch.sigmoid(logits)[0].cpu().numpy()

    preds = [label_names[i] for i, p in enumerate(probs) if p >= custom_thresholds[label_names[i]]]
    return preds, probs

# Run predictions on test reviews using updated thresholds
for i, (review, expected) in enumerate(test_reviews, 1):
    predicted_labels, probabilities = predict_custom_thresholds(review)
    print(f"\n🔹 Review #{i}")
    print(f"📝 Text: {review}")
    print(f"🎯 Expected: {expected}")
    print(f"✅ Predicted: {predicted_labels}")
    print("📊 Probabilities:", {label_names[j]: round(prob, 3) for j, prob in enumerate(probabilities)})
    print("-" * 60)
# Out:
# 🔹 Review #1
# 📝 Text: Absolutely amazing product! It exceeded my expectations!
# 🎯 Expected: ['positive']
# ✅ Predicted: ['positive']
# 📊 Probabilities: {'neutral': 0.001, 'positive': 0.993, 'mixed': 0.003, 'sarcastic': 0.011, 'negative': 0.005, 'ironic': 0.003}
# ------------------------------------------------------------
#
# 🔹 Review #2
# 📝 Text: Horrible experience, I regret buying this.
# 🎯 Expected: ['negative']
# ✅ Predicted: ['negative']
# 📊 Probabilities: {'neutral': 0.002, 'positive': 0.008, 'mixed': 0.003, 'sarcastic': 0.019, 'negative': 0.992, 'ironic': 0.007}
# ------------------------------------------------------------
#
# 🔹 Review #3
# 📝 Text: It’s okay, not great but not bad either.
# 🎯 Expected: ['neutral']
# ✅ Predicted: ['neutral', 'mixed']
# 📊 Probabilities: {'neutral': 0.461, 'positive': 0.004, 'mixed': 0.678, 'sarcastic': 0.003, 'negative': 0.006, 'ironic': 0.007}
# ------------------------------------------------------------
#
# 🔹 Review #4
# 📝 Text: I love the design, but the functionality is terrible.
# 🎯 Expected: ['mixed']
# ✅ Predicted: ['positive', 'negative']
# 📊 Probabilities: {'neutral': 0.029, 'positive': 0.906, 'mixed': 0.078, 'sarcastic': 0.003, 'negative': 0.909, 'ironic': 0.001}
# ------------------------------------------------------------
#
# 🔹 Review #5
# 📝 Text: Oh wow, just what I always wanted… NOT!
# 🎯 Expected: ['sarcastic', 'negative']
# ✅ Predicted: ['sarcastic', 'negative']
# 📊 Probabilities: {'neutral': 0.006, 'positive': 0.099, 'mixed': 0.01, 'sarcastic': 0.905, 'negative': 0.806, 'ironic': 0.049}
# ------------------------------------------------------------
#
# 🔹 Review #6
# 📝 Text: Nothing like spending hundreds on noise-cancelling headphones that let in every sound.
# 🎯 Expected: ['ironic', 'negative']
# ✅ Predicted: ['sarcastic', 'ironic']
# 📊 Probabilities: {'neutral': 0.079, 'positive': 0.0, 'mixed': 0.098, 'sarcastic': 0.334, 'negative': 0.002, 'ironic': 0.614}
# ------------------------------------------------------------
